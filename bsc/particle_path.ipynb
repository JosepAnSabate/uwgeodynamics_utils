# %%
import h5py
import pandas as pd
import numpy as np
import os

# %%
def draw_tracers(tracers=[1,2,3,4,5,6,7], 
                  data_folder_name='data'):
    #########################################
    """
    Guarda les posicions de la partícula per cada step. 
    Permet dibuixar la traça. 
    Data sources files: 
    - tip{tracer}-{time}.h5
    Final data files: 
    - tip{tracer}-{time}.h5
    - tip{tracer}-{time}.xdmf
    """
    #########################################
    
    # Check if the data folder exists
    if not os.path.exists(data_folder_name):
        raise FileNotFoundError(f"Folder '{data_folder_name}' not found.")
    
    # Check if destination folder exist
    dir_path = './my_positions/path'
    if not os.path.exists(dir_path):
        os.makedirs(dir_path)
            
    # count number of times, checking the number that files that starts with prefix
    prefix = f'tip1_velocitygradient'
    files = os.listdir(data_folder_name)
    num_files = sum([1 for file in files if file.startswith(prefix)])
    print(num_files)
    
    #loop by tracer
    for tracer in tracers:
        # loop by number of files
        time = 0
        df = pd.DataFrame(columns=["x", "y", "z"])
        while time < num_files:
            print(f'time: {time}')
            ## COORDINATES ##
            # open Coordinates H5 
            h5_file_coord =  f'./{data_folder_name}/tip{tracer}-{time}.h5'
            if not os.path.exists(h5_file_coord):
                    print(f"Warning: H5 file not found at '{h5_file_coord}'. Skipping this time step.")
                    time += 1
                    continue

            with h5py.File(h5_file_coord, 'r') as file:
                for key in file.keys():
                    np_array = file[key][:][0]
                    #print(np_array)

                custom_keys = ["x", "y", "z"]
                my_dict = dict(zip(custom_keys, np_array))
                df = df.append(my_dict, ignore_index=True)
                #print(df.dtypes)
                df = df.astype(float)
                #print(np_array[0], type(np_array[0]))
                
                filename = f'./my_positions/path/position_{tracer}_{time}.h5'
                with h5py.File(filename, 'w') as h5_file:
                  # Create a dataset within the h5 file
                  dataset = h5_file.create_dataset('data', data=df.values)

            ## XDMF file
            xdmf_text = f"""<?xml version="1.0" ?>
<Xdmf xmlns:xi="http://www.w3.org/2001/XInclude" Version="2.0">
<Domain>
<Grid Name="position_{tracer}_{time}.h5" GridType="Uniform">

    <Time Value="{time} megayear" />

    <Topology Type="POLYVERTEX" NodesPerElement="{time+1}"> </Topology>
        <Geometry Type="XYZ">
            <DataItem Format="HDF" NumberType="Float" Precision="8" Dimensions="{time + 1} 3">position_{tracer}_{time}.h5:/data</DataItem>
        </Geometry>
</Grid>
</Domain>
</Xdmf>
"""
        
            filename_xdmf = f'./my_positions/path/position_{tracer}_{time}.xdmf'
            os.makedirs(os.path.dirname(filename_xdmf), exist_ok=True)
            # Write XDMF content to file
            with open(filename_xdmf, "w") as xdmf_file:
              xdmf_file.write(xdmf_text)


            #########
            time += 1
            #print(df)

# %%
draw_tracers()
# Out:
# 27
# time: 0
# [1600.  300. -400.]
# df append
# df post append
# x    object
# y    object
# z    object
# dtype: object
# 1600.0 <class 'numpy.float64'>
# pre create h5
# time: 1
# [1599.80934935  299.19658403 -400.61979348]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 

# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1599.4688486792054 <class 'numpy.float64'>
# pre create h5
# time: 0
# [1400.        922.222222 -400.      ]
# df append
# df post append
# x    object
# y    object
# z    object
# dtype: object
# 1400.0 <class 'numpy.float64'>
# pre create h5
# time: 1
# [1400.54235011  921.84168572 -401.22745096]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1400.5423501083371 <class 'numpy.float64'>
# pre create h5
# time: 2
# [1400.92133354  921.82746144 -402.30904747]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1400.9213335422676 <class 'numpy.float64'>
# pre create h5
# time: 3
# [1401.05846125  921.99926004 -403.20571122]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1401.0584612537934 <class 'numpy.float64'>
# pre create h5
# time: 4
# [1401.21450415  921.91870461 -404.0665104 ]
# df append
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1401.2145041494184 <class 'numpy.float64'>
# pre create h5
# time: 5
# [1401.55851811  922.01728923 -404.94892513]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1401.5585181123697 <class 'numpy.float64'>
# pre create h5
# time: 6
# [1401.8311464   922.22423813 -405.85091529]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1401.8311463965306 <class 'numpy.float64'>
# pre create h5
# time: 7
# [1401.77462045  922.38364162 -406.7572482 ]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1401.7746204474245 <class 'numpy.float64'>
# pre create h5
# time: 8
# [1401.86426188  922.54471849 -407.65705451]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1401.8642618753786 <class 'numpy.float64'>
# pre create h5
# time: 9
# [1402.16003677  922.68387154 -408.5851719 ]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1402.1600367695735 <class 'numpy.float64'>
# pre create h5
# time: 10
# [1403.34713751  922.90446117 -409.83609966]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1403.347137510456 <class 'numpy.float64'>
# pre create h5
# time: 11
# [1404.32150187  923.045919   -411.1618409 ]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1404.321501867967 <class 'numpy.float64'>
# pre create h5
# time: 12
# [1405.12371632  923.03631858 -412.30830537]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1405.123716320344 <class 'numpy.float64'>
# pre create h5
# time: 13
# [1405.78999924  922.94625578 -413.40110725]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1405.789999244016 <class 'numpy.float64'>
# pre create h5
# time: 14
# [1406.59679063  922.68788579 -414.52938557]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1406.5967906304584 <class 'numpy.float64'>
# pre create h5
# time: 15
# [1407.24365702  922.67692672 -415.7444445 ]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1407.2436570211166 <class 'numpy.float64'>
# pre create h5
# time: 16
# [1407.91996929  922.58560622 -416.89860421]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1407.9199692922834 <class 'numpy.float64'>
# pre create h5
# time: 17
# [1408.44993191  922.59623125 -418.07000125]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1408.4499319114163 <class 'numpy.float64'>
# pre create h5
# time: 18
# [1409.10673605  922.45531857 -419.07112245]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1409.1067360534496 <class 'numpy.float64'>
# pre create h5
# time: 19
# [1409.16382523  922.13571052 -419.8650877 ]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1409.1638252335465 <class 'numpy.float64'>
# pre create h5
# time: 20
# [1408.90166166  921.87460068 -420.55283306]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1408.9016616551428 <class 'numpy.float64'>
# pre create h5
# time: 21
# [1408.89909108  921.67553971 -421.18654223]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1408.8990910844598 <class 'numpy.float64'>
# pre create h5
# time: 22
# [1408.51287297  921.48669383 -421.83920175]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1408.512872974449 <class 'numpy.float64'>
# pre create h5
# time: 23
# [1408.31438284  921.35258753 -422.52214389]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1408.3143828366867 <class 'numpy.float64'>
# pre create h5
# time: 24
# [1408.22801984  921.25657383 -423.24176908]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1408.2280198418275 <class 'numpy.float64'>
# pre create h5
# time: 25
# [1408.21819915  921.54798733 -424.00267569]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1408.2181991458658 <class 'numpy.float64'>
# pre create h5
# time: 26
# [1408.1565394   922.09501447 -424.74256676]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1408.1565393970136 <class 'numpy.float64'>
# pre create h5
# time: 0
# [1400.        922.222222 -600.      ]
# df append
# df post append
# x    object
# y    object
# z    object
# dtype: object
# 1400.0 <class 'numpy.float64'>
# pre create h5
# time: 1
# [1397.85121502  921.07599093 -600.54113617]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1397.8512150179229 <class 'numpy.float64'>
# pre create h5
# time: 2
# [1395.69487934  920.87431879 -601.0066272 ]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1395.69487933969 <class 'numpy.float64'>
# pre create h5
# time: 3
# [1393.56820465  921.09438061 -601.37595317]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1393.5682046539184 <class 'numpy.float64'>
# pre create h5
# time: 4
# [1391.65578914  920.72008234 -601.72214509]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1391.6557891374216 <class 'numpy.float64'>
# pre create h5
# time: 5
# [1390.14437339  920.82017057 -602.05962344]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1390.1443733884141 <class 'numpy.float64'>
# pre create h5
# time: 6
# [1388.88151336  921.16401257 -602.37734628]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1388.8815133638457 <class 'numpy.float64'>
# pre create h5
# time: 7
# [1386.79321004  921.52497391 -602.69318987]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1386.7932100353364 <class 'numpy.float64'>
# pre create h5
# time: 8
# [1385.11565224  921.97805255 -603.00244089]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1385.1156522388737 <class 'numpy.float64'>
# pre create h5
# time: 9
# [1383.65705669  922.28463051 -603.34084411]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1383.6570566889302 <class 'numpy.float64'>
# pre create h5
# time: 10
# [1381.78498788  922.91739113 -603.81503036]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1381.784987883357 <class 'numpy.float64'>
# pre create h5
# time: 11
# [1378.90223362  923.01547866 -604.28892972]
# df append
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1378.902233618197 <class 'numpy.float64'>
# pre create h5
# time: 12
# [1376.56747007  922.58438396 -604.69463401]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1376.5674700651673 <class 'numpy.float64'>
# pre create h5
# time: 13
# [1374.15376083  921.9445948  -605.05028299]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1374.1537608284311 <class 'numpy.float64'>
# pre create h5
# time: 14
# [1372.06932046  920.68405513 -605.44172794]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1372.0693204621552 <class 'numpy.float64'>
# pre create h5
# time: 15
# [1369.59038539  920.31907254 -605.83283349]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1369.5903853869452 <class 'numpy.float64'>
# pre create h5
# time: 16
# [1367.55404532  919.98622342 -606.19312801]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1367.5540453218227 <class 'numpy.float64'>
# pre create h5
# time: 17
# [1364.993547    919.95338222 -606.54227756]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1364.9935469962847 <class 'numpy.float64'>
# pre create h5
# time: 18
# [1363.4857466   919.55466715 -606.82482109]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1363.4857466036415 <class 'numpy.float64'>
# pre create h5
# time: 19
# [1361.54874184  918.87602129 -607.04620237]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1361.5487418362272 <class 'numpy.float64'>
# pre create h5
# time: 20
# [1359.56989906  918.30628052 -607.17549379]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1359.5698990596077 <class 'numpy.float64'>
# pre create h5
# time: 21
# [1358.34407777  917.89486837 -607.36012396]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1358.3440777735455 <class 'numpy.float64'>
# pre create h5
# time: 22
# [1356.23169742  917.46501911 -607.53105435]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 

# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1539.3117472082854 <class 'numpy.float64'>
# pre create h5
# time: 19
# [1539.41123985  921.44129517 -420.20485347]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1539.411239852605 <class 'numpy.float64'>
# pre create h5
# time: 20
# [1539.33909882  921.21527707 -420.92443742]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1539.3390988240942 <class 'numpy.float64'>
# pre create h5
# time: 21
# [1539.44138779  920.99875505 -421.57846483]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1539.441387787087 <class 'numpy.float64'>
# pre create h5
# time: 22
# [1539.2863533   920.84329591 -422.28399645]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1539.2863532987942 <class 'numpy.float64'>
# pre create h5
# time: 23
# [1539.2466128   920.70056364 -422.95172478]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1539.246612802267 <class 'numpy.float64'>
# pre create h5
# time: 24
# [1539.31076056  920.6355166  -423.60369407]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1539.3107605572607 <class 'numpy.float64'>
# pre create h5
# time: 25
# [1539.43511888  920.86800465 -424.26676345]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1539.4351188789924 <class 'numpy.float64'>
# pre create h5
# time: 26
# [1539.51972142  921.32431879 -424.99835371]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1539.5197214188033 <class 'numpy.float64'>
# pre create h5
# time: 0
# [1466.66666667 1233.33333    -150.        ]
# df append
# df post append
# x    object
# y    object
# z    object
# dtype: object
# 1466.6666666666667 <class 'numpy.float64'>
# pre create h5
# time: 1
# [1467.71046485 1233.33054617 -150.37904088]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1467.7104648481547 <class 'numpy.float64'>
# pre create h5
# ...
# time: 26
# [1489.84671727 1231.03969215 -157.26621768]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1489.8467172710143 <class 'numpy.float64'>
# pre create h5
# time: 0
# [1600. 1700. -400.]
# df append
# df post append
# x    object
# y    object
# z    object
# dtype: object
# 1600.0 <class 'numpy.float64'>
# pre create h5
# time: 1
# [1600.27724193 1700.32668768 -400.62418577]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1600.2772419329847 <class 'numpy.float64'>
# pre create h5
# time: 2
# [1600.40181485 1700.74887817 -401.1209201 ]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1600.401814851002 <class 'numpy.float64'>
# pre create h5
# time: 3
# [1600.4312684 1701.1117889 -401.5676524]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1600.431268395728 <class 'numpy.float64'>
# pre create h5
# time: 4
# [1600.45240244 1701.52840454 -401.92479229]
# df append
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1600.452402442095 <class 'numpy.float64'>
# pre create h5
# time: 5
# [1600.33276891 1702.07050325 -402.36499499]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1600.3327689059122 <class 'numpy.float64'>
# pre create h5
# time: 6
# [1600.21012943 1702.53611244 -402.94195917]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1600.2101294263273 <class 'numpy.float64'>
# pre create h5
# time: 7
# [1600.20835459 1702.84576066 -403.4653658 ]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1600.2083545870369 <class 'numpy.float64'>
# pre create h5
# time: 8
# [1600.40049255 1703.44607858 -403.73181994]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1600.4004925497202 <class 'numpy.float64'>
# pre create h5
# time: 9
# [1600.09354168 1704.27942149 -404.06551849]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1600.0935416770412 <class 'numpy.float64'>
# pre create h5
# time: 10
# [1599.73597035 1704.88244412 -404.67869733]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1599.735970354428 <class 'numpy.float64'>
# pre create h5
# time: 11
# [1599.7897402  1705.24520943 -405.18341689]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1599.7897402007268 <class 'numpy.float64'>
# pre create h5
# time: 12
# [1600.0287657  1705.45886515 -405.65297903]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1600.0287656970033 <class 'numpy.float64'>
# pre create h5
# time: 13
# [1600.40928221 1705.74580787 -405.96942961]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1600.4092822148173 <class 'numpy.float64'>
# pre create h5
# time: 14
# [1600.78514675 1705.93139619 -406.37291093]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1600.7851467460732 <class 'numpy.float64'>
# pre create h5
# time: 15
# [1600.9371848  1706.19949548 -406.79571677]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1600.937184799398 <class 'numpy.float64'>
# pre create h5
# time: 16
# [1601.05036498 1706.56198397 -407.19710993]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1601.050364983299 <class 'numpy.float64'>
# pre create h5
# time: 17
# [1601.28272186 1706.80898236 -407.60397705]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1601.2827218635505 <class 'numpy.float64'>
# pre create h5
# time: 18
# [1601.53398598 1707.1505551  -407.91279782]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1601.5339859789055 <class 'numpy.float64'>
# pre create h5
# time: 19
# [1601.6882047  1707.42927565 -408.19019415]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1601.6882046985872 <class 'numpy.float64'>
# pre create h5
# time: 20
# [1601.81088283 1707.59271627 -408.4882506 ]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1601.8108828267023 <class 'numpy.float64'>
# pre create h5
# time: 21
# [1601.89807969 1707.80197545 -408.76063885]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1601.8980796882931 <class 'numpy.float64'>
# pre create h5
# time: 22
# [1601.99237189 1707.98165642 -408.98893821]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1601.9923718869056 <class 'numpy.float64'>
# pre create h5
# time: 23
# [1602.14082941 1708.1196838  -409.2397274 ]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1602.1408294072635 <class 'numpy.float64'>
# pre create h5
# time: 24
# [1602.07111228 1708.41088754 -409.61391595]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1602.0711122766 <class 'numpy.float64'>
# pre create h5
# time: 25
# [1601.75656256 1708.88867904 -409.90793151]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1601.7565625613 <class 'numpy.float64'>
# pre create h5
# time: 26
# [1601.14607416 1709.47428031 -410.33349459]
# df append
# df post append
# x    float64
# y    float64
# z    float64
# dtype: object
# 1601.1460741571107 <class 'numpy.float64'>
# pre create h5
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_2215/2032282151.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)

# %%
file_text = f"""
<?xml version="1.0" ?>
<Xdmf xmlns:xi="http://www.w3.org/2001/XInclude" Version="2.0">
<Domain>
<Grid Name="position_{tracer_number}_{time}.h5" GridType="Uniform">

	<Time Value="{time} megayear" />

	<Topology Type="POLYVERTEX" NodesPerElement="{time+1}"> </Topology>
		<Geometry Type="XYZ">
			<DataItem Format="HDF" NumberType="Float" Precision="8" Dimensions="{time + 1} 3">position_{tracer_number}_{time}.h5:/data</DataItem>
		</Geometry>
</Grid>
</Domain>
</Xdmf>
"""

# %%
h5_file_coord =  f'./my_positions/position_610.h5'

with h5py.File(h5_file_coord, 'r') as file:

            for key in file.keys():
                # create a string with the name of the var, and assign numpy value from h5
                 np_array = file[key][:] 
                    

np_array[:]
df = pd.DataFrame(np_array)
df

# %%
h5_file_coord =  f'./outputs_3d_no_t_ample-moltsanys-3440-60anys/lag-5.h5'

with h5py.File(h5_file_coord, 'r') as file:

            for key in file.keys():
                # create a string with the name of the var, and assign numpy value from h5
                 np_array = file[key][:] 
                    

np_array[:]
df = pd.DataFrame(np_array)
df
