# %%
import h5py
import pandas as pd
import numpy as np
import os
import random

# %% [markdown]
# ### In Paraview:
#
#     a) Open -> CSV Reader -> Apply
#
#     b)Filtetr -> Alphabetical -> Table to Points
#
#         x = x
#         y = y
#         z = z
#
#         Apply
#
#
#     c) Filter -> Alphabetical -> Glyph
#
#     Scalable Factor 250
#
#     Apply

# %%
def create_strainrate_tensor_path(
    dir_data='./data/',
    tracers=[1,2,3,4,5,6,7]
):
           #########################################
    """
    Use lag-{time} for coordinates and lag_strainratetensor
    for plotting the strainrate tensor arrow.
    """
    #########################################
    
    # Check if the data folder exists
    if not os.path.exists(dir_data):
        raise FileNotFoundError(f"Folder '{dir_data}' not found.")
    
    # count num of timesteps
    prefix = f'tip1_strainratetensor'
    files = os.listdir(dir_data)
    num_files = sum([1 for file in files if file.startswith(prefix)])
    print(num_files)
    pd.set_option('display.precision', 20)
    
    for tracer in tracers:
        columns = ['x', 'y', 'z', 'pr_eig_x', 'pr_eig_y', 'pr_eig_z']
        df = pd.DataFrame(columns=columns)

        # loop by number of files
        time = 0
        while time < num_files:
            print('start while loop', time)
            # velfield
            h5_file =  dir_data + f'tip{tracer}_strainratetensor-{time}.h5'

            with h5py.File(h5_file, 'r') as file:
                for key in file.keys():
                    strain_rate = file[key][:][0]


            tensor = np.array([
                    [strain_rate[0], strain_rate[3], strain_rate[4]],
                    [strain_rate[3], strain_rate[1],strain_rate[5]],
                    [strain_rate[4], strain_rate[5], strain_rate[2]]
                ])


            eigenvalues, eigenvectors = np.linalg.eigh(tensor)
            # Select the principal eigenvector (corresponding to the largest eigenvalue)
            principal_index = np.argmax(eigenvalues)
            principal_eigenvector = eigenvectors[:, principal_index]


            #coordinates
            h5_file_coord =  dir_data +  f'tip{tracer}-{time}.h5'
            with h5py.File(h5_file_coord, 'r') as file:
                # create a variable name for storing strain rate tensor array
                for key in file.keys():
                    coordinates = file[key][:][0]

            # construct df row
            x = coordinates[0]
            y = coordinates[1]
            z = coordinates[2]
            pr_eig_x = principal_eigenvector[0]
            pr_eig_y = principal_eigenvector[1]
            pr_eig_z = principal_eigenvector[2]

            new_row = {'x': x, 'y': y, 'z': z, 'pr_eig_x': pr_eig_x, 'pr_eig_y': pr_eig_y, 'pr_eig_z': pr_eig_z}
            df = df.append(new_row, ignore_index=True)

            # SAVE FILE
            save_path = './strain_rate_tensor_path/'
            # Check if destination folder exist
            os.makedirs(save_path, exist_ok=True)
            df.to_csv(save_path + f'velocity_vector_{tracer}_{time}.csv', index=False)
            print(save_path + f'velocity_vector_{tracer}_{time}.csv')

            time += 1

# %%
create_strainrate_tensor_path()
# Out:
# 341
# start while loop 0
# ./strain_rate_tensor_path/velocity_vector_1_0.csv
# start while loop 1
# ./strain_rate_tensor_path/velocity_vector_1_1.csv
# start while loop 2
# ./strain_rate_tensor_path/velocity_vector_1_2.csv
# start while loop 3
# ./strain_rate_tensor_path/velocity_vector_1_3.csv
# start while loop 4
# ./strain_rate_tensor_path/velocity_vector_1_4.csv
# start while loop 5
# ./strain_rate_tensor_path/velocity_vector_1_5.csv
# start while loop 6
# ./strain_rate_tensor_path/velocity_vector_1_6.csv
# start while loop 7
# ./strain_rate_tensor_path/velocity_vector_1_7.csv
# start while loop 8
# ./strain_rate_tensor_path/velocity_vector_1_8.csv
# start while loop 9
# ./strain_rate_tensor_path/velocity_vector_1_9.csv
# start while loop 10
# ./strain_rate_tensor_path/velocity_vector_1_10.csv
# start while loop 11
# ./strain_rate_tensor_path/velocity_vector_1_11.csv
# start while loop 12
# ./strain_rate_tensor_path/velocity_vector_1_12.csv
# start while loop 13
# ./strain_rate_tensor_path/velocity_vector_1_13.csv
# start while loop 14
# ./strain_rate_tensor_path/velocity_vector_1_14.csv
# start while loop 15
# ./strain_rate_tensor_path/velocity_vector_1_15.csv
# start while loop 16
# ./strain_rate_tensor_path/velocity_vector_1_16.csv
# start while loop 17
# ./strain_rate_tensor_path/velocity_vector_1_17.csv
# start while loop 18
# ./strain_rate_tensor_path/velocity_vector_1_18.csv
# start while loop 19
# ./strain_rate_tensor_path/velocity_vector_1_19.csv
# start while loop 20
# ./strain_rate_tensor_path/velocity_vector_1_20.csv
# start while loop 21
# ./strain_rate_tensor_path/velocity_vector_1_21.csv
# start while loop 22
# ./strain_rate_tensor_path/velocity_vector_1_22.csv
# start while loop 23
# ./strain_rate_tensor_path/velocity_vector_1_23.csv
# start while loop 24
# ./strain_rate_tensor_path/velocity_vector_1_24.csv
# start while loop 25
# ./strain_rate_tensor_path/velocity_vector_1_25.csv
# start while loop 26
# ./strain_rate_tensor_path/velocity_vector_1_26.csv
# start while loop 27
# ./strain_rate_tensor_path/velocity_vector_1_27.csv
# start while loop 28
# ./strain_rate_tensor_path/velocity_vector_1_28.csv
# start while loop 29
# ./strain_rate_tensor_path/velocity_vector_1_29.csv
# start while loop 30
# ./strain_rate_tensor_path/velocity_vector_1_30.csv
# start while loop 31
# ./strain_rate_tensor_path/velocity_vector_1_31.csv
# start while loop 32
# ./strain_rate_tensor_path/velocity_vector_1_32.csv
# start while loop 33
# ./strain_rate_tensor_path/velocity_vector_1_33.csv
# start while loop 34
# ./strain_rate_tensor_path/velocity_vector_1_34.csv
# start while loop 35
# ./strain_rate_tensor_path/velocity_vector_1_35.csv
# start while loop 36
# ./strain_rate_tensor_path/velocity_vector_1_36.csv
# start while loop 37
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# ./strain_rate_tensor_path/velocity_vector_1_37.csv
# start while loop 38
# ./strain_rate_tensor_path/velocity_vector_1_38.csv
# start while loop 39
# ./strain_rate_tensor_path/velocity_vector_1_39.csv
# start while loop 40
# ./strain_rate_tensor_path/velocity_vector_1_40.csv
# start while loop 41
# ./strain_rate_tensor_path/velocity_vector_1_41.csv
# start while loop 42
# ./strain_rate_tensor_path/velocity_vector_1_42.csv
# start while loop 43
# ./strain_rate_tensor_path/velocity_vector_1_43.csv
# start while loop 44
# ./strain_rate_tensor_path/velocity_vector_1_44.csv
# start while loop 45
# ./strain_rate_tensor_path/velocity_vector_1_45.csv
# start while loop 46
# ./strain_rate_tensor_path/velocity_vector_1_46.csv
# start while loop 47
# ./strain_rate_tensor_path/velocity_vector_1_47.csv
# start while loop 48
# ./strain_rate_tensor_path/velocity_vector_1_48.csv
# start while loop 49
# ./strain_rate_tensor_path/velocity_vector_1_49.csv
# start while loop 50
# ./strain_rate_tensor_path/velocity_vector_1_50.csv
# start while loop 51
# ./strain_rate_tensor_path/velocity_vector_1_51.csv
# start while loop 52
# ./strain_rate_tensor_path/velocity_vector_1_52.csv
# start while loop 53
# ./strain_rate_tensor_path/velocity_vector_1_53.csv
# start while loop 54
# ./strain_rate_tensor_path/velocity_vector_1_54.csv
# start while loop 55
# ./strain_rate_tensor_path/velocity_vector_1_55.csv
# start while loop 56
# ./strain_rate_tensor_path/velocity_vector_1_56.csv
# start while loop 57
# ./strain_rate_tensor_path/velocity_vector_1_57.csv
# start while loop 58
# ./strain_rate_tensor_path/velocity_vector_1_58.csv
# start while loop 59
# ./strain_rate_tensor_path/velocity_vector_1_59.csv
# start while loop 60
# ./strain_rate_tensor_path/velocity_vector_1_60.csv
# start while loop 61
# ./strain_rate_tensor_path/velocity_vector_1_61.csv
# start while loop 62
# ./strain_rate_tensor_path/velocity_vector_1_62.csv
# start while loop 63
# ./strain_rate_tensor_path/velocity_vector_1_63.csv
# start while loop 64
# ./strain_rate_tensor_path/velocity_vector_1_64.csv
# start while loop 65
# ./strain_rate_tensor_path/velocity_vector_1_65.csv
# start while loop 66
# ./strain_rate_tensor_path/velocity_vector_1_66.csv
# start while loop 67
# ./strain_rate_tensor_path/velocity_vector_1_67.csv
# start while loop 68
# ./strain_rate_tensor_path/velocity_vector_1_68.csv
# start while loop 69
# ./strain_rate_tensor_path/velocity_vector_1_69.csv
# start while loop 70
# ./strain_rate_tensor_path/velocity_vector_1_70.csv
# start while loop 71
# ./strain_rate_tensor_path/velocity_vector_1_71.csv
# start while loop 72
# ./strain_rate_tensor_path/velocity_vector_1_72.csv
# start while loop 73
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# ./strain_rate_tensor_path/velocity_vector_1_73.csv
# start while loop 74
# ./strain_rate_tensor_path/velocity_vector_1_74.csv
# start while loop 75
# ./strain_rate_tensor_path/velocity_vector_1_75.csv
# start while loop 76
# ./strain_rate_tensor_path/velocity_vector_1_76.csv
# start while loop 77
# ./strain_rate_tensor_path/velocity_vector_1_77.csv
# start while loop 78
# ./strain_rate_tensor_path/velocity_vector_1_78.csv
# start while loop 79
# ./strain_rate_tensor_path/velocity_vector_1_79.csv
# start while loop 80
# ./strain_rate_tensor_path/velocity_vector_1_80.csv
# start while loop 81
# ./strain_rate_tensor_path/velocity_vector_1_81.csv
# start while loop 82
# ./strain_rate_tensor_path/velocity_vector_1_82.csv
# start while loop 83
# ./strain_rate_tensor_path/velocity_vector_1_83.csv
# start while loop 84
# ./strain_rate_tensor_path/velocity_vector_1_84.csv
# start while loop 85
# ./strain_rate_tensor_path/velocity_vector_1_85.csv
# start while loop 86
# ./strain_rate_tensor_path/velocity_vector_1_86.csv
# start while loop 87
# ./strain_rate_tensor_path/velocity_vector_1_87.csv
# start while loop 88
# ./strain_rate_tensor_path/velocity_vector_1_88.csv
# start while loop 89
# ./strain_rate_tensor_path/velocity_vector_1_89.csv
# start while loop 90
# ./strain_rate_tensor_path/velocity_vector_1_90.csv
# start while loop 91
# ./strain_rate_tensor_path/velocity_vector_1_91.csv
# start while loop 92
# ./strain_rate_tensor_path/velocity_vector_1_92.csv
# start while loop 93
# ./strain_rate_tensor_path/velocity_vector_1_93.csv
# start while loop 94
# ./strain_rate_tensor_path/velocity_vector_1_94.csv
# start while loop 95
# ./strain_rate_tensor_path/velocity_vector_1_95.csv
# start while loop 96
# ./strain_rate_tensor_path/velocity_vector_1_96.csv
# start while loop 97
# ./strain_rate_tensor_path/velocity_vector_1_97.csv
# start while loop 98
# ./strain_rate_tensor_path/velocity_vector_1_98.csv
# start while loop 99
# ./strain_rate_tensor_path/velocity_vector_1_99.csv
# start while loop 100
# ./strain_rate_tensor_path/velocity_vector_1_100.csv
# start while loop 101
# ./strain_rate_tensor_path/velocity_vector_1_101.csv
# start while loop 102
# ./strain_rate_tensor_path/velocity_vector_1_102.csv
# start while loop 103
# ./strain_rate_tensor_path/velocity_vector_1_103.csv
# start while loop 104
# ./strain_rate_tensor_path/velocity_vector_1_104.csv
# start while loop 105
# ./strain_rate_tensor_path/velocity_vector_1_105.csv
# start while loop 106
# ./strain_rate_tensor_path/velocity_vector_1_106.csv
# start while loop 107
# ./strain_rate_tensor_path/velocity_vector_1_107.csv
# start while loop 108
# ./strain_rate_tensor_path/velocity_vector_1_108.csv
# start while loop 109
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# ./strain_rate_tensor_path/velocity_vector_1_109.csv
# start while loop 110
# ./strain_rate_tensor_path/velocity_vector_1_110.csv
# start while loop 111
# ./strain_rate_tensor_path/velocity_vector_1_111.csv
# start while loop 112
# ./strain_rate_tensor_path/velocity_vector_1_112.csv
# start while loop 113
# ./strain_rate_tensor_path/velocity_vector_1_113.csv
# start while loop 114
# ./strain_rate_tensor_path/velocity_vector_1_114.csv
# start while loop 115
# ./strain_rate_tensor_path/velocity_vector_1_115.csv
# start while loop 116
# ./strain_rate_tensor_path/velocity_vector_1_116.csv
# start while loop 117
# ./strain_rate_tensor_path/velocity_vector_1_117.csv
# start while loop 118
# ./strain_rate_tensor_path/velocity_vector_1_118.csv
# start while loop 119
# ./strain_rate_tensor_path/velocity_vector_1_119.csv
# start while loop 120
# ./strain_rate_tensor_path/velocity_vector_1_120.csv
# start while loop 121
# ./strain_rate_tensor_path/velocity_vector_1_121.csv
# start while loop 122
# ./strain_rate_tensor_path/velocity_vector_1_122.csv
# start while loop 123
# ./strain_rate_tensor_path/velocity_vector_1_123.csv
# start while loop 124
# ./strain_rate_tensor_path/velocity_vector_1_124.csv
# start while loop 125
# ./strain_rate_tensor_path/velocity_vector_1_125.csv
# start while loop 126
# ./strain_rate_tensor_path/velocity_vector_1_126.csv
# start while loop 127
# ./strain_rate_tensor_path/velocity_vector_1_127.csv
# start while loop 128
# ./strain_rate_tensor_path/velocity_vector_1_128.csv
# start while loop 129
# ./strain_rate_tensor_path/velocity_vector_1_129.csv
# start while loop 130
# ./strain_rate_tensor_path/velocity_vector_1_130.csv
# start while loop 131
# ./strain_rate_tensor_path/velocity_vector_1_131.csv
# start while loop 132
# ./strain_rate_tensor_path/velocity_vector_1_132.csv
# start while loop 133
# ./strain_rate_tensor_path/velocity_vector_1_133.csv
# start while loop 134
# ./strain_rate_tensor_path/velocity_vector_1_134.csv
# start while loop 135
# ./strain_rate_tensor_path/velocity_vector_1_135.csv
# start while loop 136
# ./strain_rate_tensor_path/velocity_vector_1_136.csv
# start while loop 137
# ./strain_rate_tensor_path/velocity_vector_1_137.csv
# start while loop 138
# ./strain_rate_tensor_path/velocity_vector_1_138.csv
# start while loop 139
# ./strain_rate_tensor_path/velocity_vector_1_139.csv
# start while loop 140
# ./strain_rate_tensor_path/velocity_vector_1_140.csv
# start while loop 141
# ./strain_rate_tensor_path/velocity_vector_1_141.csv
# start while loop 142
# ./strain_rate_tensor_path/velocity_vector_1_142.csv
# start while loop 143
# ./strain_rate_tensor_path/velocity_vector_1_143.csv
# start while loop 144
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# ./strain_rate_tensor_path/velocity_vector_1_144.csv
# start while loop 145
# ./strain_rate_tensor_path/velocity_vector_1_145.csv
# start while loop 146
# ./strain_rate_tensor_path/velocity_vector_1_146.csv
# start while loop 147
# ./strain_rate_tensor_path/velocity_vector_1_147.csv
# start while loop 148
# ./strain_rate_tensor_path/velocity_vector_1_148.csv
# start while loop 149
# ./strain_rate_tensor_path/velocity_vector_1_149.csv
# start while loop 150
# ./strain_rate_tensor_path/velocity_vector_1_150.csv
# start while loop 151
# ./strain_rate_tensor_path/velocity_vector_1_151.csv
# start while loop 152
# ./strain_rate_tensor_path/velocity_vector_1_152.csv
# start while loop 153
# ./strain_rate_tensor_path/velocity_vector_1_153.csv
# start while loop 154
# ./strain_rate_tensor_path/velocity_vector_1_154.csv
# start while loop 155
# ./strain_rate_tensor_path/velocity_vector_1_155.csv
# start while loop 156
# ./strain_rate_tensor_path/velocity_vector_1_156.csv
# start while loop 157
# ./strain_rate_tensor_path/velocity_vector_1_157.csv
# start while loop 158
# ./strain_rate_tensor_path/velocity_vector_1_158.csv
# start while loop 159
# ./strain_rate_tensor_path/velocity_vector_1_159.csv
# start while loop 160
# ./strain_rate_tensor_path/velocity_vector_1_160.csv
# start while loop 161
# ./strain_rate_tensor_path/velocity_vector_1_161.csv
# start while loop 162
# ./strain_rate_tensor_path/velocity_vector_1_162.csv
# start while loop 163
# ./strain_rate_tensor_path/velocity_vector_1_163.csv
# start while loop 164
# ./strain_rate_tensor_path/velocity_vector_1_164.csv
# start while loop 165
# ./strain_rate_tensor_path/velocity_vector_1_165.csv
# start while loop 166
# ./strain_rate_tensor_path/velocity_vector_1_166.csv
# start while loop 167
# ./strain_rate_tensor_path/velocity_vector_1_167.csv
# start while loop 168
# ./strain_rate_tensor_path/velocity_vector_1_168.csv
# start while loop 169
# ./strain_rate_tensor_path/velocity_vector_1_169.csv
# start while loop 170
# ./strain_rate_tensor_path/velocity_vector_1_170.csv
# start while loop 171
# ./strain_rate_tensor_path/velocity_vector_1_171.csv
# start while loop 172
# ./strain_rate_tensor_path/velocity_vector_1_172.csv
# start while loop 173
# ./strain_rate_tensor_path/velocity_vector_1_173.csv
# start while loop 174
# ./strain_rate_tensor_path/velocity_vector_1_174.csv
# start while loop 175
# ./strain_rate_tensor_path/velocity_vector_1_175.csv
# start while loop 176
# ./strain_rate_tensor_path/velocity_vector_1_176.csv
# start while loop 177
# ./strain_rate_tensor_path/velocity_vector_1_177.csv
# start while loop 178
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# ...
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# ./strain_rate_tensor_path/velocity_vector_7_291.csv
# start while loop 292
# ./strain_rate_tensor_path/velocity_vector_7_292.csv
# start while loop 293
# ./strain_rate_tensor_path/velocity_vector_7_293.csv
# start while loop 294
# ./strain_rate_tensor_path/velocity_vector_7_294.csv
# start while loop 295
# ./strain_rate_tensor_path/velocity_vector_7_295.csv
# start while loop 296
# ./strain_rate_tensor_path/velocity_vector_7_296.csv
# start while loop 297
# ./strain_rate_tensor_path/velocity_vector_7_297.csv
# start while loop 298
# ./strain_rate_tensor_path/velocity_vector_7_298.csv
# start while loop 299
# ./strain_rate_tensor_path/velocity_vector_7_299.csv
# start while loop 300
# ./strain_rate_tensor_path/velocity_vector_7_300.csv
# start while loop 301
# ./strain_rate_tensor_path/velocity_vector_7_301.csv
# start while loop 302
# ./strain_rate_tensor_path/velocity_vector_7_302.csv
# start while loop 303
# ./strain_rate_tensor_path/velocity_vector_7_303.csv
# start while loop 304
# ./strain_rate_tensor_path/velocity_vector_7_304.csv
# start while loop 305
# ./strain_rate_tensor_path/velocity_vector_7_305.csv
# start while loop 306
# ./strain_rate_tensor_path/velocity_vector_7_306.csv
# start while loop 307
# ./strain_rate_tensor_path/velocity_vector_7_307.csv
# start while loop 308
# ./strain_rate_tensor_path/velocity_vector_7_308.csv
# start while loop 309
# ./strain_rate_tensor_path/velocity_vector_7_309.csv
# start while loop 310
# ./strain_rate_tensor_path/velocity_vector_7_310.csv
# start while loop 311
# ./strain_rate_tensor_path/velocity_vector_7_311.csv
# start while loop 312
# ./strain_rate_tensor_path/velocity_vector_7_312.csv
# start while loop 313
# ./strain_rate_tensor_path/velocity_vector_7_313.csv
# start while loop 314
# ./strain_rate_tensor_path/velocity_vector_7_314.csv
# start while loop 315
# ./strain_rate_tensor_path/velocity_vector_7_315.csv
# start while loop 316
# ./strain_rate_tensor_path/velocity_vector_7_316.csv
# start while loop 317
# ./strain_rate_tensor_path/velocity_vector_7_317.csv
# start while loop 318
# ./strain_rate_tensor_path/velocity_vector_7_318.csv
# start while loop 319
# ./strain_rate_tensor_path/velocity_vector_7_319.csv
# start while loop 320
# ./strain_rate_tensor_path/velocity_vector_7_320.csv
# start while loop 321
# ./strain_rate_tensor_path/velocity_vector_7_321.csv
# start while loop 322
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# ./strain_rate_tensor_path/velocity_vector_7_322.csv
# start while loop 323
# ./strain_rate_tensor_path/velocity_vector_7_323.csv
# start while loop 324
# ./strain_rate_tensor_path/velocity_vector_7_324.csv
# start while loop 325
# ./strain_rate_tensor_path/velocity_vector_7_325.csv
# start while loop 326
# ./strain_rate_tensor_path/velocity_vector_7_326.csv
# start while loop 327
# ./strain_rate_tensor_path/velocity_vector_7_327.csv
# start while loop 328
# ./strain_rate_tensor_path/velocity_vector_7_328.csv
# start while loop 329
# ./strain_rate_tensor_path/velocity_vector_7_329.csv
# start while loop 330
# ./strain_rate_tensor_path/velocity_vector_7_330.csv
# start while loop 331
# ./strain_rate_tensor_path/velocity_vector_7_331.csv
# start while loop 332
# ./strain_rate_tensor_path/velocity_vector_7_332.csv
# start while loop 333
# ./strain_rate_tensor_path/velocity_vector_7_333.csv
# start while loop 334
# ./strain_rate_tensor_path/velocity_vector_7_334.csv
# start while loop 335
# ./strain_rate_tensor_path/velocity_vector_7_335.csv
# start while loop 336
# ./strain_rate_tensor_path/velocity_vector_7_336.csv
# start while loop 337
# ./strain_rate_tensor_path/velocity_vector_7_337.csv
# start while loop 338
# ./strain_rate_tensor_path/velocity_vector_7_338.csv
# start while loop 339
# ./strain_rate_tensor_path/velocity_vector_7_339.csv
# start while loop 340
# ./strain_rate_tensor_path/velocity_vector_7_340.csv
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
# /tmp/ipykernel_2339/371473208.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)

# %% [markdown]
# # Coordenades

# %%
h5_file_coord =  f'./data/tip4-26.h5'


with h5py.File(h5_file_coord, 'r') as file:
    # create a variable name to store coord
    dataset_name = f'np_array_5'

    for key in file.keys():
        # create a string with the name of the var, and assign numpy value from h5
        coord = file[key][:] 

coord
# Out:
# array([[1489.45226293,  923.6673247 , -157.08672313]])

# %%
h5_file_coord =  f'./data/tip4-27.h5'


with h5py.File(h5_file_coord, 'r') as file:
    # create a variable name to store coord
    dataset_name = f'np_array_5'

    for key in file.keys():
        # create a string with the name of the var, and assign numpy value from h5
        coord = file[key][:] 

coord
# Out:
# array([[1490.24577104,  923.73118169, -157.33445744]])

# %% [markdown]
# # Strai rate tensor

# %%
h5_file_coord =  f'./data/tip4_strainratetensor-26.h5'

with h5py.File(h5_file_coord, 'r') as file:
    # create a variable name for storing strain rate tensor array
    dataset_name = f'np_array_6'

    for key in file.keys():
        dataset_name = file[key][:] 

                    
dataset_name[0]
# Out:
# array([-3.1864208e-17, -2.8831913e-17,  3.8581666e-17, -6.6733390e-19,
#        -1.7424990e-17,  4.3317927e-18], dtype=float32)

# %%
h5_file_coord =  f'./data/tip4_strainratetensor-27.h5'

with h5py.File(h5_file_coord, 'r') as file:
    # create a variable name for storing strain rate tensor array
    dataset_name = f'np_array_6'

    for key in file.keys():
        dataset_name = file[key][:] 

                    
dataset_name[0]
# Out:
# array([-4.7088001e-17, -3.1932467e-17,  4.8947016e-17, -5.8125109e-18,
#        -3.7677266e-17, -1.9897719e-17], dtype=float32)

# %%
 tensor = np.array([
        [strain_rate[0], strain_rate[3], strain_rate[4]],
        [strain_rate[3], strain_rate[1],strain_rate[5]],
        [strain_rate[4], strain_rate[5], strain_rate[2]]
    ])

# %%
eigenvalues, eigenvectors = np.linalg.eigh(tensor)

# %%
eigenvalues, eigenvectors
# Out:
# (array([-4.9081970e-16,  1.5045583e-17,  1.0559194e-15], dtype=float32),
#  array([[ 0.53737485, -0.22331978, -0.81323826],
#         [ 0.60244304,  0.7764582 ,  0.18486497],
#         [-0.59016156,  0.58927155, -0.5517866 ]], dtype=float32))

# %%
# Select the principal eigenvector (corresponding to the largest eigenvalue)
principal_index = np.argmax(eigenvalues)
principal_eigenvector = eigenvectors[:, principal_index]

# %%
principal_eigenvector
# Out:
# array([-0.81323826,  0.18486497, -0.5517866 ], dtype=float32)

# %%
principal_index
# Out:
# 2

# %%
data = {
    'x': 1500,
    'y': [coordinates[0]],
    'z': [coordinates[2]],
    'pr_eig_x': [principal_eigenvector[0]],
    'pr_eig_y': [principal_eigenvector[1]],
    'pr_eig_z': [principal_eigenvector[2]]
}

df = pd.DataFrame(data)
df.head()
# Out:
#       x           y           z  pr_eig_x  pr_eig_y  pr_eig_z
# 0  1500  1404.07338 -150.590597 -0.813238  0.184865 -0.551787

# %%
df.to_csv('strain_rate_eigenvectors.csv', index=False)
