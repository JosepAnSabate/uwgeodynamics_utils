# %%
import h5py
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### Quins fitxers faig servir?
#
# tip_velocitygradient, tip_time
#
# ### Com sestructura cada fitxer?

# %%
def draw_tracers(tracer_number=3, 
                 tracers='tip', data_folder_name='data'):
    #########################################
    """
    Guarda les posicions de la partícula per cada step. 
    Permet dibuixar la traça. 
    """
    #########################################
    
    # Check if the data folder exists
    if not os.path.exists(data_folder_name):
        raise FileNotFoundError(f"Folder '{data_folder_name}' not found.")
    
    # Check if destination folder exist
    dir_path = './my_positions/path'
    if not os.path.exists(dir_path):
        os.makedirs(dir_path)
            
    # count number of times, checking the number that files that starts with prefix
    prefix = f'{tracers}_velocitygradient'
    files = os.listdir(data_folder_name)
    num_files = sum([1 for file in files if file.startswith(prefix)])
    print(num_files)
    # loop by number of files
    time = 0
    df = pd.DataFrame(columns=["x", "y", "z"])
    while time < num_files:
        print(f'time: {time}')
        ## COORDINATES ##
        # open Coordinates H5 
        h5_file_coord =  f'./{data_folder_name}/{tracers}-{time}.h5'
        if not os.path.exists(h5_file_coord):
                print(f"Warning: H5 file not found at '{h5_file_coord}'. Skipping this time step.")
                time += 1
                continue
        
        with h5py.File(h5_file_coord, 'r') as file:
            for key in file.keys():
                np_array = file[key][tracer_number]
        
            custom_keys = ["x", "y", "z"]
            my_dict = dict(zip(custom_keys, np_array))
            df = df.append(my_dict, ignore_index=True)
            df = df.astype(float)
            filename = f'./my_positions/path/position_{tracer_number}_{time}.h5'
            with h5py.File(filename, 'w') as h5_file:
              # Create a dataset within the h5 file
              dataset = h5_file.create_dataset('data', data=df.values)
        
        ## XDMF file
        xdmf_text = f"""<?xml version="1.0" ?>
<Xdmf xmlns:xi="http://www.w3.org/2001/XInclude" Version="2.0">
<Domain>
<Grid Name="position_{tracer_number}_{time}.h5" GridType="Uniform">

    <Time Value="{time} megayear" />

    <Topology Type="POLYVERTEX" NodesPerElement="{time+1}"> </Topology>
        <Geometry Type="XYZ">
            <DataItem Format="HDF" NumberType="Float" Precision="8" Dimensions="{time + 1} 3">position_{tracer_number}_{time}.h5:/data</DataItem>
        </Geometry>
</Grid>
</Domain>
</Xdmf>
"""
        
        filename_xdmf = f'./my_positions/path/position_{tracer_number}_{time}.xdmf'
        os.makedirs(os.path.dirname(filename_xdmf), exist_ok=True)
        # Write XDMF content to file
        with open(filename_xdmf, "w") as xdmf_file:
          xdmf_file.write(xdmf_text)

      

        
        #########
        time += 1
        #print(df)
        
        
    ### save the df as csv
    #df.to_csv('./my_positions/position_{tracer_number}.csv')
    #df = df.astype(float)
    #filename = f'./my_positions/position_{tracer_number}.h5'
    #with h5py.File(filename, 'w') as h5_file:
      # Create a dataset within the h5 file
    #  dataset = h5_file.create_dataset('data', data=df.values)

# %%
n_part = [0,1,2,3,4,5,6]
for n_p in n_part:
    draw_tracers(tracer_number=n_p)
# Out:
# 301
# time: 0
# time: 1
# time: 2
# time: 3
# time: 4
# time: 5
# time: 6
# time: 7
# time: 8
# time: 9
# time: 10
# time: 11
# time: 12
# time: 13
# time: 14
# time: 15
# time: 16
# time: 17
# time: 18
# time: 19
# time: 20
# time: 21
# time: 22
# time: 23
# time: 24
# time: 25
# time: 26
# time: 27
# time: 28
# time: 29
# time: 30
# time: 31
# time: 32
# time: 33
# time: 34
# time: 35
# time: 36
# time: 37
# time: 38
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# /tmp/ipykernel_1355/1577776637.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(my_dict, ignore_index=True)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [6], in <module>
#       1 n_part = [0,1,2,3,4,5,6]
#       2 for n_p in n_part:
# ----> 3     draw_tracers(tracer_number=n_p)
#
# Input In [4], in draw_tracers(tracer_number, tracers, data_folder_name)
#      37 with h5py.File(h5_file_coord, 'r') as file:
#      38     for key in file.keys():
# ---> 39         np_array = file[key][tracer_number]
#      41     custom_keys = ["x", "y", "z"]
#      42     my_dict = dict(zip(custom_keys, np_array))
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File /opt/venv/lib/python3.9/site-packages/h5py/_hl/dataset.py:710, in Dataset.__getitem__(self, args, new_dtype)
#     708 if self._fast_read_ok and (new_dtype is None):
#     709     try:
# --> 710         return self._fast_reader.read(args)
#     711     except TypeError:
#     712         pass  # Fall back to Python read pathway below
#
# File h5py/_selector.pyx:351, in h5py._selector.Reader.read()
#
# File h5py/_selector.pyx:151, in h5py._selector.Selector.apply_args()
#
# IndexError: Index (3) out of range for (0-2)

# %%
draw_tracers()
# Out:
# 301
# time: 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [8], in <module>
# ----> 1 draw_tracers()
#
# Input In [7], in draw_tracers(tracer_number, tracers, data_folder_name)
#      37 with h5py.File(h5_file_coord, 'r') as file:
#      38     for key in file.keys():
# ---> 39         np_array = file[key][tracer_number]
#      41     custom_keys = ["x", "y", "z"]
#      42     my_dict = dict(zip(custom_keys, np_array))
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File /opt/venv/lib/python3.9/site-packages/h5py/_hl/dataset.py:710, in Dataset.__getitem__(self, args, new_dtype)
#     708 if self._fast_read_ok and (new_dtype is None):
#     709     try:
# --> 710         return self._fast_reader.read(args)
#     711     except TypeError:
#     712         pass  # Fall back to Python read pathway below
#
# File h5py/_selector.pyx:351, in h5py._selector.Reader.read()
#
# File h5py/_selector.pyx:151, in h5py._selector.Selector.apply_args()
#
# IndexError: Index (3) out of range for (0-2)

# %%
file_text = f"""
<?xml version="1.0" ?>
<Xdmf xmlns:xi="http://www.w3.org/2001/XInclude" Version="2.0">
<Domain>
<Grid Name="position_{tracer_number}_{time}.h5" GridType="Uniform">

	<Time Value="{time} megayear" />

	<Topology Type="POLYVERTEX" NodesPerElement="{time+1}"> </Topology>
		<Geometry Type="XYZ">
			<DataItem Format="HDF" NumberType="Float" Precision="8" Dimensions="{time + 1} 3">position_{tracer_number}_{time}.h5:/data</DataItem>
		</Geometry>
</Grid>
</Domain>
</Xdmf>
"""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <module>
#       1 file_text = f"""
#       2 <?xml version="1.0" ?>
#       3 <Xdmf xmlns:xi="http://www.w3.org/2001/XInclude" Version="2.0">
#       4 <Domain>
# ----> 5 <Grid Name="position_{tracer_number}_{time}.h5" GridType="Uniform">
#       6
#       7 	<Time Value="{time} megayear" />
#       8
#       9 	<Topology Type="POLYVERTEX" NodesPerElement="{time+1}"> </Topology>
#      10 		<Geometry Type="XYZ">
#      11 			<DataItem Format="HDF" NumberType="Float" Precision="8" Dimensions="{time + 1} 3">position_{tracer_number}_{time}.h5:/data</DataItem>
#      12 		</Geometry>
#      13 </Grid>
#      14 </Domain>
#      15 </Xdmf>
#      16 """
#
# NameError: name 'tracer_number' is not defined

# %%
h5_file_coord =  f'./my_positions/path/position_135_0.h5'

with h5py.File(h5_file_coord, 'r') as file:

            for key in file.keys():
                # create a string with the name of the var, and assign numpy value from h5
                 np_array = file[key][:] 
                    

np_array[:]
df = pd.DataFrame(np_array)
df
# Out:
#              0       1      2
# 0  1866.666667  1250.0 -600.0

# %%
h5_file_coord =  f'./data_p/tip-1.h5'

with h5py.File(h5_file_coord, 'r') as file:

            for key in file.keys():
                # create a string with the name of the var, and assign numpy value from h5
                 np_array = file[key][:] 
                    

np_array[:]
df = pd.DataFrame(np_array)
df
# Out:
#              0            1           2
# 0  1600.128476   454.980801 -401.035047
# 1  1733.583287   921.934147 -400.593724
# 2  1600.521556  1544.466380 -400.918692

# %%
h5_file_coord =  f'./data_p/tip_velocitygradient-1.h5'

with h5py.File(h5_file_coord, 'r') as file:

            for key in file.keys():
                # create a string with the name of the var, and assign numpy value from h5
                 np_array = file[key][:] 
                    

np_array[:]
df = pd.DataFrame(np_array)
df
# Out:
#               0             1             2             3             4  \
# 0  7.259619e-17  1.996495e-17  8.171243e-16 -2.740976e-17  2.029339e-17
# 1 -7.111254e-17  1.325494e-17  4.814289e-16  3.354163e-17 -1.330835e-17
# 2 -5.055072e-19 -3.647725e-18  5.177175e-16  9.482509e-17  7.856518e-17
#
#               5             6             7             8
# 0  1.051774e-16  3.704328e-16 -7.139793e-17 -7.686178e-17
# 1  9.666123e-17  2.365220e-16  1.630602e-18  1.835811e-17
# 2  3.921336e-17  3.226792e-16  1.000581e-16 -6.593624e-17

# %%
h5_file_coord =  f'./data/lag-136.h5'

with h5py.File(h5_file_coord, 'r') as file:

            for key in file.keys():
                # create a string with the name of the var, and assign numpy value from h5
                 np_array = file[key][:] 
                    

np_array[:]
df = pd.DataFrame(np_array)
df
# Out:
#                0            1           2
# 0    1312.532613   169.738386 -597.343984
# 1    1351.978845   171.401462 -551.382657
# 2    1394.896965   156.665667 -603.605777
# 3    1734.108877   153.076966 -550.910317
# 4    1636.111558   150.553300 -552.049844
# ..           ...          ...         ...
# 995  1992.361060  1740.471536 -196.946216
# 996  2079.888215  1721.161938 -155.971762
# 997  2057.344590  1740.172066 -197.879489
# 998  1814.787126  1718.027661 -144.911819
# 999  1799.384174  1745.448070 -182.278340
#
# [1000 rows x 3 columns]

# %%
h5_file_coord =  f'/home/jovyan/workspace/Desktop/mite_outputs/test_temp_final/data/lag-15.h5'

with h5py.File(h5_file_coord, 'r') as file:

            for key in file.keys():
                # create a string with the name of the var, and assign numpy value from h5
                 np_array = file[key][:] 
                    

np_array[:]
df = pd.DataFrame(np_array)
df
# Out:
#                0            1           2
# 0    1367.708433   288.020483 -127.175592
# 1    1360.316514   284.833411 -174.098949
# 2    1349.607037   278.174303 -223.122327
# 3    1335.583247   270.931461 -274.003186
# 4    1320.034675   264.527638 -325.434468
# ..           ...          ...         ...
# 995  1910.956290  2761.299280 -387.830384
# 996  1896.221988  2764.638729 -439.437667
# 997  1882.197717  2768.087555 -491.375232
# 998  1870.101356  2770.962867 -543.487675
# 999  1860.817897  2773.288835 -595.871522
#
# [1000 rows x 3 columns]

# %%
# !pwd
# Out:
# /home/jovyan/workspace/Desktop/bsc_outputs/y2000_x4000_150_05
